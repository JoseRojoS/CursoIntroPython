# %% [markdown]
# ## Prácticas Módulo 10 - Manejo de errores - Katas 10

# %% [markdown]
# ### Tracebacks

# %%
open("/path/to/mars.jpg")

# %% [markdown]
# Intenta crear un archivo de Python y asígnale el nombre open.py, con el contenido siguiente:

# %%
def main():
    open("/path/to/mars.jpg")

if __name__ == '__main__':
    main()

# %%
from IPython.display import Image
Image(filename='Kata10-1.png')

# %% [markdown]
# ### Controlando las excepciones
#
# #### Try y Except de los bloques - try - except

# %%
try:
    open('config.txt')
except FileNotFoundError:
    print("Couldn't find the config.txt file!")

# %% [markdown]
# ### Archivo .txt

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")


if __name__ == '__main__':
    main()
# Out:
# Couldn't find the config.txt file!

# %% [markdown]
# ### Archivo .txt a .py

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("No pudimos encontrar el archivo config.txt")


if __name__ == '__main__':
    main()
# Out:
# No pudimos encontrar el archivo config.txt

# %% [markdown]
# ### Nuevo directorio.txt

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("No pudimos encontrar el archivo config.txt")


if __name__ == '__main__':
    main()

# %%
from IPython.display import Image
Image(filename='Kata10-2.png')

# %% [markdown]
# ### Agregamos otro bloque except para detectar PermissionError

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")
    except IsADirectoryError:
        print("Found config.txt but it is a directory, couldn't read it")

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")


if __name__ == '__main__':
    main()
# Out:
# Couldn't find the config.txt file!

# %%
from IPython.display import Image
Image(filename='Kata10-3.png')

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
water_left(5, 100, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Rojo\Documents\Onboarding Launch X BET\CursoIntroPython\Modulo10Katas.ipynb Cell 21' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rojo/Documents/Onboarding%20Launch%20X%20BET/CursoIntroPython/Modulo10Katas.ipynb#ch0000028?line=0'>1</a> water_left(5, 100, 2)
#
# c:\Users\Rojo\Documents\Onboarding Launch X BET\CursoIntroPython\Modulo10Katas.ipynb Cell 20' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell:/c%3A/Users/Rojo/Documents/Onboarding%20Launch%20X%20BET/CursoIntroPython/Modulo10Katas.ipynb#ch0000027?line=3'>4</a> total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell:/c%3A/Users/Rojo/Documents/Onboarding%20Launch%20X%20BET/CursoIntroPython/Modulo10Katas.ipynb#ch0000027?line=4'>5</a> if total_water_left < 0:
# ...
