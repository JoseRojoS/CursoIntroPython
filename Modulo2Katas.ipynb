# %% [markdown]
# # Módulo 2 - Crear y administrar proyectos - Kata 2

# %% [markdown]
# ## Ejercicio - Crear un paquete

# %% [markdown]
# ### Crear un entorno virtual

# %%
from IPython.display import Image
Image(filename='Kata2-1.png')

# %% [markdown]
# ### Instalar una biblioteca

# %%
from IPython.display import Image
Image(filename='Kata2-2.png')

# %%
from IPython.display import Image
Image(filename='Kata2-3.png')

# %% [markdown]
# ### Desactivar un entorno virtual

# %%
from IPython.display import Image
Image(filename='Kata2-4.png')
